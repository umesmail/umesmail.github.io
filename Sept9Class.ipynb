# %% [markdown]
# <a href="https://colab.research.google.com/github/umesmail/umesmail.github.io/blob/main/Sept9Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,100)
y= x**3
fig, ax = plt. subplots()
ax.plot (x,y)
ax.set_xlabel("this is my x")
ax.set_ylabel("y axis")
plt.show()

# %%
import panda
